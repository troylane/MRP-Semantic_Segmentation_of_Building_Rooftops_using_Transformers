# %%
from PIL import Image

# %% [markdown]
# Get image size

# %%
im = Image.open('IMG_608_84_mask.png')
im.size
# Out:
# (768, 768)

# %%
im.mode
# Out:
# 'RGB'

# %%
im.getbands()
# Out:
# ('R', 'G', 'B')

# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline
pic = imageio.imread('christchurch_173_vis.tif')
plt.figure(figsize = (5,5))
plt.imshow(pic)

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Hight {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (10000, 10000)
# Image Hight 10000
# Image Width 10000
# Dimension of Image 2

# %%
print('Image size {}'.format(pic.size)) 
print('Maximum RGB value in this image {}'.format(pic.max())) 
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 9820160
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
print('Value of only R channel {}'.format(pic[ 800, 1000, 0])) 
print('Value of only G channel {}'.format(pic[ 800, 1000, 1])) 
print('Value of only B channel {}'.format(pic[ 800, 1000, 2]))
# Out:
# Value of only R channel 255
# Value of only G channel 255
# Value of only B channel 255

# %%
plt.title('R channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 1]) 
plt.show()

# %%
plt.title('B channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 2]) 
plt.show()

# %%
import numpy as np 
pic = imageio.imread("IMG_608_84_img.png") 

fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5)) 

plt.axis('off')
for c, ax in zip(range(3), ax):     
    # create zero matrix        
    plt.axis('off')
    split_img = np.zeros(pic.shape, dtype="uint8") 
    # 'dtype' by default: 'numpy.float64'  # assing each channel      
    
    split_img[ :, :, c] = pic[ :, :, c] # display each channel     
    
    ax.imshow(split_img)

# %%
pic = imageio.imread("IMG_608_84_img.png") 
gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114])   
gray = gray(pic) 
plt.figure( figsize = (5,5))  
plt.imshow(gray, cmap = plt.get_cmap(name = 'gray')) 
plt.show()

# %%
# Only Red Pixel value , higher than 180
pic = imageio.imread("IMG_608_84_img.png")
red_mask = pic[:, :, 0] < 180
pic[red_mask] = 0
plt.figure(figsize=(5,5))
plt.imshow(pic)

# Only Green Pixel value , higher than 180
pic = imageio.imread('IMG_608_84_img.png')
green_mask = pic[:, :, 1] < 180
pic[green_mask] = 0
plt.figure(figsize=(5,5))
plt.imshow(pic)
# Only Blue Pixel value , higher than 180
pic = imageio.imread('IMG_608_84_img.png')
blue_mask = pic[:, :, 2] < 180
pic[blue_mask] = 0
plt.figure(figsize=(5,5))
plt.imshow(pic)
# Composite mask using logical_and
pic = imageio.imread('IMG_608_84_img.png')
final_mask = np.logical_and(red_mask, green_mask, blue_mask)
pic[final_mask] = 40
plt.figure(figsize=(5,5))
plt.imshow(pic)

# %% [markdown]
# Diplsay image

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
#im = Image.open("christchurch_77_vis.tif")
im = Image.open("IMG_608_84.png")

# %%
im1 = Image.Image.getdata(im)

# %%
print(im1)

# %% [markdown]
# Display image using cv2

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# Load an color image in grayscale
img = cv2.imread('IMG_608_84.png',3)

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('IMG_608_84_img.png',3)
plt.imshow(img, interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
img.shape
# Out:
# (768, 768, 3)

# %%
img = cv2.imread('IMG_608_84_mask.png')
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
img.shape
# Out:
# (768, 768, 3)

# %%
img.resize((256,256))

# %%
img.shape
# Out:
# (256, 256)

# %%
len(img.shape)
# Out:
# 3

# %%
img_arr = np.array(img)

# %%
px = np.sum(img_arr)
print(px)
# Out:
# 979968825

# %%
white = np.sum(img_arr == 255)
print(white)
# Out:
# 3843015

# %%
black = np.sum(img_arr == 0)
print(black)
# Out:
# 96156985

# %%
white/px * 100
# Out:
# 0.39215686274509803

# %%
black/px *100
# Out:
# 9.812249384565881
